# %%
import os
import runpy

SCRIPT_DIR = os.path.dirname(os.path.abspath(__file__)) if "__file__" in globals() else os.getcwd()

pipeline = [
    "01_data_collection_cleaning.py",
    "02_exploratory_data_analysis.py",
    "03_statistical_analysis.py",
    "04_predictive_analytics_ml.py",
    "05_risk_fraud_anomaly_detection.py",
    "06_prescriptive_analytics.py",
    "07_export_for_powerbi.py",
]

for script in pipeline:
    path = os.path.join(SCRIPT_DIR, script)
    print("\n" + "=" * 100)
    print(f"RUNNING: {script}")
    print("=" * 70)
    runpy.run_path(path, run_name="__main__")

print("\n\nPipeline complete. Check data/processed/, visuals/, and python/saved_models/.")
# Out:
# ====================================================================================================
# RUNNING: 01_data_collection_cleaning.py
# ======================================================================
# Project root: C:\Users\Victor M\Documents\business 2.0\Codveda_Business_Analytics_Project
# Combined raw records: 3333 rows x 21 columns
# State                         str
# Account length              int64
# Area code                   int64
# International plan            str
# Voice mail plan               str
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls             int64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls             int64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls           int64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls      int64
# Churn                        bool
# source_split                  str
# dtype: object
#
# Missing values per column:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# source_split              0
# dtype: int64
#
# Duplicate rows: 0
# ['state', 'account_length', 'area_code', 'international_plan', 'voice_mail_plan', 'number_vmail_messages', 'total_day_minutes', 'total_day_calls', 'total_day_charge', 'total_eve_minutes', 'total_eve_calls', 'total_eve_charge', 'total_night_minutes', 'total_night_calls', 'total_night_charge', 'total_intl_minutes', 'total_intl_calls', 'total_intl_charge', 'customer_service_calls', 'churn', 'source_split']
# Numeric columns: ['account_length', 'area_code', 'number_vmail_messages', 'total_day_minutes', 'total_day_calls', 'total_day_charge', 'total_eve_minutes', 'total_eve_calls', 'total_eve_charge', 'total_night_minutes', 'total_night_calls', 'total_night_charge', 'total_intl_minutes', 'total_intl_calls', 'total_intl_charge', 'customer_service_calls']
# Categorical columns: ['state', 'international_plan', 'voice_mail_plan', 'churn', 'source_split']
#
# Total missing values: 0 -> 0
# Dropped 0 duplicate rows. Remaining: 3333
# C:\Users\Victor M\Documents\business 2.0\Codveda_Business_Analytics_Project\python\01_data_collection_cleaning.py:88: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_cols = df.select_dtypes(include=["object", "bool"]).columns.tolist()
#                         lower_fence  upper_fence  n_outliers
# total_day_minutes            34.650      325.450        25.0
# total_day_charge              5.890       55.330        25.0
# total_eve_minutes            63.550      338.350        24.0
# total_eve_charge              5.400       28.760        24.0
# total_night_minutes          64.550      337.750        30.0
# total_night_charge            2.915       15.195        30.0
# total_intl_minutes            3.100       17.500        46.0
# total_intl_charge             0.845        4.725        49.0
# customer_service_calls       -0.500        3.500       267.0
#                            column    dtype  n_missing  n_unique
# 0                     customer_id      str          0      3333
# 1                           state      str          0        51
# 2                  account_length    int64          0       212
# 3                       area_code    int64          0         3
# 4              international_plan      str          0         2
# 5                 voice_mail_plan      str          0         2
# 6           number_vmail_messages    int64          0        46
# 7               total_day_minutes  float64          0      1645
# 8                 total_day_calls    int64          0       119
# 9                total_day_charge  float64          0      1645
# 10              total_eve_minutes  float64          0      1589
# 11                total_eve_calls    int64          0       123
# 12               total_eve_charge  float64          0      1418
# 13            total_night_minutes  float64          0      1564
# 14              total_night_calls    int64          0       120
# 15             total_night_charge  float64          0       906
# 16             total_intl_minutes  float64          0       142
# 17               total_intl_calls    int64          0        21
# 18              total_intl_charge  float64          0       142
# 19         customer_service_calls  float64          0         5
# 20                          churn     bool          0         2
# 21                   source_split      str          0         2
# 22                     churn_flag    int64          0         2
# 23                  total_minutes  float64          0      2577
# 24                   total_charge  float64          0      2711
# 25                    total_calls    int64          0       195
# 26            avg_charge_per_call  float64          0      3318
# 27                  has_intl_plan    int64          0         2
# 28             has_voicemail_plan    int64          0         2
# 29          account_length_zscore  float64          0       212
# 30       total_day_minutes_zscore  float64          0      1645
# 31       total_eve_minutes_zscore  float64          0      1589
# 32     total_night_minutes_zscore  float64          0      1564
# 33      total_intl_minutes_zscore  float64          0       142
# 34            total_charge_zscore  float64          0      2711
# 35  customer_service_calls_zscore  float64          0         5
# 36            account_length_norm  float64          0       212
# 37         total_day_minutes_norm  float64          0      1645
# 38         total_eve_minutes_norm  float64          0      1589
# 39       total_night_minutes_norm  float64          0      1564
# 40        total_intl_minutes_norm  float64          0       142
# 41              total_charge_norm  float64          0      2662
# 42    customer_service_calls_norm  float64          0         5
# Train: (2666, 43), Test: (667, 43)
# Saved: churn_cleaned.csv, churn_train.csv, churn_test.csv, data_dictionary.csv, outlier_report.csv
#
# Done with Task: Data Collection & Cleaning.
#
# ====================================================================================================
# RUNNING: 02_exploratory_data_analysis.py
# ======================================================================
# (3333, 43)
#                                        mean      median        mode        std         min         max
# account_length                 1.010648e+02  101.000000  105.000000  39.822106    1.000000  243.000000
# area_code                      4.371824e+02  415.000000  415.000000  42.371290  408.000000  510.000000
# number_vmail_messages          8.099010e+00    0.000000    0.000000  13.688365    0.000000   51.000000
# total_day_minutes              1.798162e+02  179.400000   34.650000  54.152190   34.650000  325.450000
# total_day_calls                1.004356e+02  101.000000  102.000000  20.069084    0.000000  165.000000
# total_day_charge               3.056929e+01   30.500000    5.890000   9.205865    5.890000   55.330000
# total_eve_minutes              2.010095e+02  201.400000   63.550000  50.401365   63.550000  338.350000
# total_eve_calls                1.001143e+02  100.000000  105.000000  19.922625    0.000000  170.000000
# total_eve_charge               1.708602e+01   17.120000    5.400000   4.284135    5.400000   28.760000
# total_night_minutes            2.008281e+02  201.200000   64.550000  50.118622   64.550000  337.750000
# total_night_calls              1.001077e+02  100.000000  105.000000  19.568609   33.000000  175.000000
# total_night_charge             9.037381e+00    9.050000    2.915000   2.255212    2.915000   15.195000
# total_intl_minutes             1.025458e+01   10.300000   10.000000   2.721007    3.100000   17.500000
# total_intl_calls               4.479448e+00    4.000000    3.000000   2.461214    0.000000   20.000000
# total_intl_charge              2.769320e+00    2.780000    2.700000   0.734445    0.845000    4.725000
# customer_service_calls         1.476298e+00    1.000000    1.000000   1.107194    0.000000    3.500000
# churn_flag                     1.449145e-01    0.000000    0.000000   0.352067    0.000000    1.000000
# total_minutes                  5.919084e+02  593.700000  522.600000  89.268378  284.300000  882.200000
# total_charge                   5.946201e+01   59.470000   52.980000  10.433074   27.020000   92.520000
# total_calls                    3.051371e+02  305.000000  314.000000  34.448164  191.000000  416.000000
# avg_charge_per_call            1.973804e-01    0.194393    0.146725   0.041565    0.071263    0.409718
# has_intl_plan                  9.690969e-02    0.000000    0.000000   0.295879    0.000000    1.000000
# has_voicemail_plan             2.766277e-01    0.000000    0.000000   0.447398    0.000000    1.000000
# account_length_zscore          1.449652e-16   -0.001628    0.098834   1.000150   -2.513172    3.564766
# total_day_minutes_zscore       2.099864e-16   -0.007686   -2.681109   1.000150   -2.681109    2.689747
# total_eve_minutes_zscore      -3.645449e-16    0.007748   -2.727707   1.000150   -2.727707    2.725344
# total_night_minutes_zscore     1.359049e-16    0.007421   -2.719520   1.000150   -2.719520    2.732366
# total_intl_minutes_zscore     -1.769428e-16    0.016697   -0.093573   1.000150   -2.629780    2.663173
# total_charge_zscore            3.837315e-17    0.000766    0.554857   1.000150   -3.110002    3.169052
# customer_service_calls_zscore -1.343060e-16   -0.430249   -0.430249   1.000150   -1.333569    1.828050
# account_length_norm            4.134909e-01    0.413223    0.429752   0.164554    0.000000    1.000000
# total_day_minutes_norm         4.991959e-01    0.497765    0.000000   0.186218    0.000000    1.000000
# total_eve_minutes_norm         5.002167e-01    0.501638    0.000000   0.183411    0.000000    1.000000
# total_night_minutes_norm       4.988219e-01    0.500183    0.000000   0.183450    0.000000    1.000000
# total_intl_minutes_norm        4.968455e-01    0.500000    0.479167   0.188959    0.000000    1.000000
# total_charge_norm              4.952978e-01    0.495420    0.534198   0.159284    0.000000    1.000000
# customer_service_calls_norm    4.217993e-01    0.285714    0.285714   0.316341    0.000000    1.000000
# Overall churn rate: 14.49%
#
# Top 10 states by churn rate:
# state
# CA    26.470588
# NJ    26.470588
# TX    25.000000
# MD    24.285714
# SC    23.333333
# MI    21.917808
# MS    21.538462
# WA    21.212121
# NV    21.212121
# ME    20.967742
# Name: churn_flag, dtype: float64
# churn_flag                1.000000
# total_charge              0.231025
# total_day_minutes         0.204788
# customer_service_calls    0.152404
# total_eve_minutes         0.092109
# total_intl_minutes        0.066554
# total_night_minutes       0.036176
# account_length            0.016541
# Name: churn_flag, dtype: float64
#
# All EDA visuals saved to: C:\Users\Victor M\Documents\business 2.0\Codveda_Business_Analytics_Project\visuals
# Done with Task: Exploratory Data Analysis.
#
# ====================================================================================================
# RUNNING: 03_statistical_analysis.py
# ======================================================================
# T-test (total_day_minutes, churn vs stay): t=9.697, p=0.00000 -> Reject H0: means differ significantly
# T-test (customer_service_calls, churn vs stay): t=7.589, p=0.00000 -> Reject H0: means differ significantly
#
# Chi-square (international_plan vs churn): chi2=222.566, p=0.000000, dof=1 -> Reject H0: variables are dependent (associated)
# Chi-square (voice_mail_plan vs churn): chi2=34.132, p=0.000000 -> Reject H0: dependent
#
# Churn rate: 14.49%
# 95% CI: [13.30%, 15.69%]  (margin of error = 1.20 pp)
#
# Poisson(lambda=1.48) fitted to service calls.
# P(service calls > 4) = 0.0175
# Empirical P(service calls > 4) = 0.0000
#
# A/B test — Group A (control) churn: 14.67%, Group B (campaign) churn: 1.33%
# z=4.256, p=0.00002 -> Campaign significantly reduces churn
#
# Saved statistical_test_results.csv
#                                   test   statistic       p_value                                       conclusion
# 0    t-test: day minutes churn vs stay    9.696980  1.092784e-20            Reject H0: means differ significantly
# 1  t-test: service calls churn vs stay    7.588892  1.264146e-13            Reject H0: means differ significantly
# 2       chi-square: intl plan vs churn  222.565757  2.493108e-50  Reject H0: variables are dependent (associated)
# 3  chi-square: voicemail plan vs churn   34.131660  5.150640e-09                             Reject H0: dependent
# 4            95% CI churn rate (lower)    0.132964           NaN                     point est=0.1449, MOE=0.0120
# 5            95% CI churn rate (upper)    0.156865           NaN
# 6     P(service_calls > 4) via Poisson    1.476298  1.748228e-02                        risk probability estimate
# 7         A/B test: retention campaign    4.256283  2.078539e-05             Campaign significantly reduces churn
#
# Done with Task: Statistical Analysis for Business Decisions.
#
# ====================================================================================================
# RUNNING: 04_predictive_analytics_ml.py
# ======================================================================
# Train: (2666, 43), Test: (667, 43)
# [Linear Regression] RMSE=0.006, R2=1.0000
# [Random Forest Regressor] RMSE=1.163, R2=0.9871
#
# [Logistic Regression] Accuracy=0.7481 Precision=0.3301 Recall=0.7113 F1=0.4510 ROC-AUC=0.8015
#               precision    recall  f1-score   support
#
#       Stayed       0.94      0.75      0.84       570
#      Churned       0.33      0.71      0.45        97
#
#     accuracy                           0.75       667
#    macro avg       0.63      0.73      0.64       667
# weighted avg       0.85      0.75      0.78       667
#
#
# [Random Forest Classifier] Accuracy=0.9445 Precision=0.8261 Recall=0.7835 F1=0.8042 ROC-AUC=0.9436
#               precision    recall  f1-score   support
#
#       Stayed       0.96      0.97      0.97       570
#      Churned       0.83      0.78      0.80        97
#
#     accuracy                           0.94       667
#    macro avg       0.89      0.88      0.89       667
# weighted avg       0.94      0.94      0.94       667
#
# total_day_minutes         0.258805
# customer_service_calls    0.140046
# has_intl_plan             0.110139
# total_eve_minutes         0.093059
# total_intl_minutes        0.067513
# total_night_minutes       0.061928
# total_day_calls           0.044838
# total_intl_calls          0.044441
# account_length            0.043634
# total_night_calls         0.043396
# total_eve_calls           0.041801
# number_vmail_messages     0.032154
# has_voicemail_plan        0.018245
# dtype: float64
# Best k by silhouette score: 2
#
# Segment profiles:
#                   total_day_minutes  total_eve_minutes  total_night_minutes  total_intl_minutes  customer_service_calls  account_length  churn_flag
# customer_segment
# 0                        180.364776         201.950426           200.889457           10.254420                0.628860      101.602769    0.113951
# 1                        179.108041         199.795120           200.749003           10.254777                2.570103      100.370447    0.184880
# predicted_churn_risk_tier
# Low       2731
# High       441
# Medium     161
# Name: count, dtype: int64
#
# Saved model_predictions.csv, customer_segment_profiles.csv, classification_model_comparison.csv
# Saved trained models to python/saved_models/
# Done with Task: Predictive Analytics & Machine Learning.
#
# ====================================================================================================
# RUNNING: 05_risk_fraud_anomaly_detection.py
# ======================================================================
# Isolation Forest flagged 100 anomalous records (3.00%)
# Records flagged as anomalous by BOTH methods (higher confidence fraud/risk candidates): 53
# risk_tier
# Low       2814
# Medium     479
# High        40
# Name: count, dtype: int64
#
# Top 10 highest-risk customers:
#      state  account_length  customer_service_calls  total_intl_calls  high_confidence_anomaly  predicted_churn_probability  risk_score risk_tier
# 2668    NY             161                     3.5                 9                        1                     0.982803   99.484088      High
# 1097    OK             101                     3.0                15                        1                     0.973355   90.907156      High
# 780     NY              64                     1.0                 9                        1                     0.998344   89.111541      High
# 3215    OR              81                     0.0                 5                        1                     0.977854   86.716995      High
# 413     AL              60                     0.0                12                        0                     0.979607   86.257582      High
# 1589    TX              73                     1.0                14                        1                     0.964008   86.114901      High
# 1917    NV              42                     1.0                 3                        0                     0.977190   85.747596      High
# 2722    OK              89                     1.0                 3                        0                     0.979053   83.754818      High
# 35      MD             135                     0.0                15                        0                     0.994907   83.317797      High
# 3017    MA              34                     2.0                10                        0                     0.976681   82.595478      High
#
# Saved customer_risk_scores.csv
# Done with Task: Risk Analysis & Fraud Detection.
#
# ====================================================================================================
# RUNNING: 06_prescriptive_analytics.py
# ======================================================================
# risk_tier
# Low       2814
# Medium     479
# High        40
# Name: count, dtype: int64
# risk_tier
# High        40
# Medium     479
# Low       2814
# Name: count, dtype: int64
# Optimal outreach allocation (customers to contact per tier):
# High       40
# Medium    479
# Low       189
# dtype: int64
#
# Expected annualized retained value: $78,974
# Budget used: $4,999 / $5000
# Staff hours used: 158.7 / 400
#
# Scenario analysis (budget vs expected retained value):
#    budget  expected_retained_value
# 0    2000                  32760.0
# 1    5000                  78974.4
# 2    8000                 114974.4
# 3   12000                 162974.4
# 4   20000                 165848.4
#
# Monte Carlo (n=10000) — Expected retained value distribution:
# Mean: $79,007, Median: $79,008
# 5th percentile (pessimistic): $50,378
# 95th percentile (optimistic): $107,753
#
# --- PRESCRIPTIVE RECOMMENDATIONS ---
# 1. Contact 40 'High-risk' customers via a phone call + discount offer; estimated 35% chance of retaining each, at $15/customer.
# 2. Contact 479 'Medium-risk' customers via a targeted email + discount offer; estimated 18% chance of retaining each, at $8/customer.
# 3. Contact 189 'Low-risk' customers via an automated email nudge; estimated 5% chance of retaining each, at $3/customer.
# 4. At the current $5000 budget, expected annualized value protected is ~$78,974 (Monte Carlo 90% interval: $50,378 - $107,753).
# 5. Scenario analysis shows returns keep scaling well beyond the current budget — consider requesting a larger retention budget next cycle.
#
# Saved optimal_retention_allocation.csv, budget_scenario_analysis.csv, prescriptive_recommendations.txt
# Done with Task: Prescriptive Analytics & Strategic Decision Making.
#
# ====================================================================================================
# RUNNING: 07_export_for_powerbi.py
# ======================================================================
# Saved Power BI–ready workbook: C:\Users\Victor M\Documents\business 2.0\Codveda_Business_Analytics_Project\data\processed\churn_for_powerbi.xlsx
# Sheets: KPI_Summary, Customer_Detail, Churn_Predictions, Risk_Scores, By_State, By_Plan_Type
#
#
# Pipeline complete. Check data/processed/, visuals/, and python/saved_models/.
